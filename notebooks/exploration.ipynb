# %% [markdown]
# # Exploration Notebook
# Optional notebook for ad-hoc analysis of GitHub Peru Analytics datasets.

# %%
import pandas as pd
users = pd.read_csv('../data/processed/users.csv')
repos = pd.read_csv('../data/processed/repositories.csv')
classifications = pd.read_csv('../data/processed/classifications.csv')
print('users', len(users), 'repos', len(repos), 'classifications', len(classifications))
